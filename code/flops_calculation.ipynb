# %%
from tensorflow.keras.models import load_model
from keras_flops import get_flops

# %%
model_path = 'D:/Anil/saved_model/SACNN/SA_CNN/SA_ResNet_tomato_adam_100_epochs.hdf5'
model = load_model(model_path)
model.summary()
# Out:
# Model: "SAResNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 258, 258, 8)  224         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 258, 258, 8)  32          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 258, 258, 8)  0           bn_conv1[0][0]
# ...

# %%
# Calculate FLOPS
flops = get_flops(model,batch_size=1)
print(f'FLOPS: {flops/10**9:.03} G')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x00000277B18D6DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x00000277B18D6DC8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# ...

# %%
wsa_model_path = 'D:/Anil/saved_model/SACNN/WSA_CNN/WSA_ResNet_tomato_adam_70_epochs.hdf5'
wsa_model = load_model(wsa_model_path)
wsa_model.summary()
# Out:
# Model: "ResNet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 260, 260, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 258, 258, 8)  224         zero_padding2d[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 258, 258, 8)  32          conv1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 258, 258, 8)  0           bn_conv1[0][0]
# ...

# %%
# Calculate FLOPS
flops = get_flops(wsa_model,batch_size=1)
print(f'FLOPS: {flops/10**9:.03} G')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x0000027988A2CF48> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x0000027988A2CF48> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# FLOPS: 0.468 G

# %%
# FLOPS calculation for ResNet models from tensorflow
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet import ResNet101,ResNet152
from tensorflow.keras.models import Model

# %%
base_model = ResNet101(input_shape =(256,256,3), include_top = False)
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(11, activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=x)
model.summary()
# Out:
# ...
# 171450368/171446536 [==============================] - 17s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# Calculate FLOPS
flops = get_flops(model,batch_size=1)
print(f'FLOPS: {flops/10**9:.03} G')
# Out:
# WARNING:tensorflow:AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x00000279888E4E08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <tensorflow.python.keras.engine.functional.Functional object at 0x00000279888E4E08> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# FLOPS: 19.8 G
