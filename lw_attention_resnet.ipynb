# %%
# This is attention based residual network architecture design
from __future__ import print_function
import keras
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from tensorflow.keras.layers import AveragePooling2D,GlobalAveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from datetime import datetime

# attention modules importing
import attention_modules
from attention_modules import attach_attention_module
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\USER\Anil\tomato_expt\dual_attention.py:6: experimental_run_functions_eagerly (from tensorflow.python.eager.def_function) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.run_functions_eagerly` instead of the experimental version.

# %%
def identity_block(X, f, filters, stage, block, attention_module=None):
    """
    Implementation of the identity block for a RseNet model
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    
    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # attention module
    #if attention_module is not None:
    #    Y = attach_attention_module(X, attention_module)
    #X = Add()([X_shortcut, Y])
    
    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2, attention_module=None):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path (≈3 lines)
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)


    # Third component of main path (≈2 lines)
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)


    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = Conv2D(filters = F3, kernel_size = (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1',
                        kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # attention modules added
    if attention_module is not None:
        X = attach_attention_module(X, attention_module)
    X = Add()([X, X_shortcut])
    
    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    #X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    
    return X

# %%
def LW_ResNet20(input_shape=(224, 224, 3), classes=11, attention_module=None):
    """
    Implementation of the custom ResNet20 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> CONVBLOCK -> IDBLOCK*1
    -> CONVBLOCK -> IDBLOCK*1 -> CONVBLOCK -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)

    # Stage 1
    X = Conv2D(16, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f=3, filters=[16, 16, 64], stage=2, block='a', s=1)
   
    ### START CODE HERE ###

    # Stage 3 (≈4 lines)
    X = convolutional_block(X, f = 3, filters = [32, 32, 128], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [32, 32, 128], stage=3, block='b')
       
    # Stage 4 (≈6 lines)
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 4, block='a', s = 2, attention_module=attention_module)
    X = identity_block(X, 3, [64, 64, 256], stage=4, block='b')
   
    # Stage 5 (≈3 lines)
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 5, block='a', s = 2)
    #X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    #X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL (≈1 line). Use "X = AveragePooling2D(...)(X)"
    #X = AveragePooling2D((2,2), name="avg_pool")(X)
    X = GlobalAveragePooling2D(name="avg_pool")(X)

    ### END CODE HERE ###

    # output layer
    #X = Flatten()(X)
    X = Dense(classes, activation='softmax', name='fc_' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    # for naming the model
    if attention_module is not None:
        attention_name = '_'+attention_module.split('_')[0]
    else:
        attention_name = ''
    # Create model
    model = Model(inputs = X_input, outputs = X, name='LW_ResNet20'+attention_name)

    return model

# %%
model = LW_ResNet20(input_shape = (256, 256, 3), classes = 11, attention_module='da_module')
model.summary()
# Out:
# Model: "LW_ResNet20_da"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 262, 262, 3)  0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 16) 2368        zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 128, 128, 16) 64          conv1[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 128, 128, 16) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 63, 63, 16)   0           activation_33[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 63, 63, 16)   272         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 63, 63, 16)   64          res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 63, 63, 16)   0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 63, 63, 16)   2320        activation_34[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 63, 63, 16)   64          res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 63, 63, 16)   0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 63, 63, 64)   1088        activation_35[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 63, 63, 64)   1088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 63, 63, 64)   256         res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 63, 63, 64)   256         res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 63, 63, 64)   0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 63, 63, 64)   0           add_10[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 32, 32, 32)   2080        activation_36[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 32, 32, 32)   128         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 32, 32, 32)   0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 32, 32, 32)   9248        activation_37[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 32, 32, 32)   128         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 32, 32, 32)   0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 32, 32, 128)  4224        activation_38[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 32, 32, 128)  8320        activation_36[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 32, 32, 128)  512         res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 32, 32, 128)  512         res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 32, 32, 128)  0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 32, 32, 128)  0           add_11[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 32, 32, 32)   4128        activation_39[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 32, 32, 32)   128         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 32)   0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 32, 32, 32)   9248        activation_40[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 32, 32, 32)   128         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 32)   0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 32, 32, 128)  4224        activation_41[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 32, 32, 128)  512         res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 32, 32, 128)  0           bn3b_branch2c[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32, 32, 128)  0           add_12[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a (Conv2D)         (None, 16, 16, 64)   8256        activation_42[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a (BatchNormalizati (None, 16, 16, 64)   256         res4a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16, 16, 64)   0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 16, 16, 64)   36928       activation_43[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 16, 16, 64)   256         res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16, 16, 64)   0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 16, 16, 256)  16640       activation_44[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 16, 16, 256)  1024        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 32)   8192        bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 32)   8192        bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# tf.reshape_7 (TFOpLambda)       (None, 256, 32)      0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_10 (TFOpLambda)      (None, 256, 256)     0           bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# tf.reshape_6 (TFOpLambda)       (None, 256, 32)      0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_2 (TFOpL (None, 32, 256)      0           tf.reshape_7[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_3 (TFOpL (None, 256, 256)     0           tf.reshape_10[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_4 (TFOpLambda) (None, 256, 256)     0           tf.reshape_6[0][0]
#                                                                  tf.compat.v1.transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 256)  65536       bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_6 (TFOpLambda) (None, 256, 256)     0           tf.compat.v1.transpose_3[0][0]
#                                                                  tf.reshape_10[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 256, 256)     0           tf.linalg.matmul_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_8 (TFOpLambda)       (None, 256, 256)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 256, 256)     0           tf.linalg.matmul_6[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_5 (TFOpLambda) (None, 256, 256)     0           activation_45[0][0]
#                                                                  tf.reshape_8[0][0]
# __________________________________________________________________________________________________
# tf.linalg.matmul_7 (TFOpLambda) (None, 256, 256)     0           tf.reshape_10[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# tf.reshape_9 (TFOpLambda)       (None, 16, 16, 256)  0           tf.linalg.matmul_5[0][0]
# __________________________________________________________________________________________________
# tf.reshape_11 (TFOpLambda)      (None, 16, 16, 256)  0           tf.linalg.matmul_7[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 16, 16, 256)  0           tf.reshape_9[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_3 (TFOpLambda) (None, 16, 16, 256)  0           tf.reshape_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_2 (TFOpLam (None, 16, 16, 256)  0           tf.math.multiply_2[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_3 (TFOpLam (None, 16, 16, 256)  0           tf.math.multiply_3[0][0]
#                                                                  bn4a_branch2c[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 16, 16, 256)  33024       activation_42[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 256)  0           tf.__operators__.add_2[0][0]
#                                                                  tf.__operators__.add_3[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 16, 16, 256)  1024        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 16, 16, 256)  0           add_13[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 16, 16, 256)  0           add_14[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 16, 16, 64)   16448       activation_47[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 16, 16, 64)   256         res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 16, 16, 64)   0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 16, 16, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 16, 16, 64)   256         res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 16, 16, 64)   0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 16, 16, 256)  16640       activation_49[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 16, 16, 256)  1024        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 16, 16, 256)  0           bn4b_branch2c[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 16, 16, 256)  0           add_15[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 8, 8, 256)    65792       activation_50[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 8, 8, 256)    1024        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8, 8, 256)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 8, 8, 256)    590080      activation_51[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 8, 8, 256)    1024        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8, 8, 256)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 8, 8, 1024)   263168      activation_52[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 8, 8, 1024)   263168      activation_50[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 8, 8, 1024)   4096        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 8, 8, 1024)   4096        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 1024)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8, 8, 1024)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 1024)         0           activation_53[0][0]
# __________________________________________________________________________________________________
# fc_11 (Dense)                   (None, 11)           11275       avg_pool[0][0]
# ==================================================================================================
# Total params: 1,505,963
# Trainable params: 1,497,419
# Non-trainable params: 8,544
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# %%
# image preprocessing
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   rotation_range=40,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)


batch_size = 32

train_data_dir = "D:/Anil/Dataset/tomato/train"     # directory of training data

test_data_dir = "D:/Anil/Dataset/tomato/val"      # directory of Validation data

training_set = train_datagen.flow_from_directory(train_data_dir,
                                                 target_size=(256, 256),
                                                 batch_size=batch_size,
                                                 class_mode='categorical')

test_set = test_datagen.flow_from_directory(test_data_dir,
                                            target_size=(256, 256),
                                            batch_size=batch_size,
                                            class_mode='categorical')

print(training_set.class_indices)
# Out:
# Found 15156 images belonging to 11 classes.
# Found 1891 images belonging to 11 classes.
# {'bacterial_spot': 0, 'early_blight': 1, 'fusarium_wilt': 2, 'healthy': 3, 'late_blight': 4, 'leaf_mold': 5, 'mosaic_virus': 6, 'septoria_leaf_spot': 7, 'spider_mites': 8, 'target_spot': 9, 'yellow_leaf_curl_virus': 10}

# %%
# checkpoint
weightpath = "CBAM-keras/saved_models/LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5"
checkpointer = ModelCheckpoint(weightpath, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

epochs = 100

start_time = datetime.now()
print("start time: "+str(start_time))

#fitting images to CNN
history = model.fit(training_set,
                         steps_per_epoch=training_set.samples//batch_size,
                         validation_data=test_set,
                         epochs=epochs,
                         validation_steps=test_set.samples//batch_size,
                         callbacks=[checkpointer])#callbacks_list)


# #fitting images to CNN
# history = classifier.fit_generator(training_set,
#                                    steps_per_epoch=training_set.samples//batch_size,
#                                    validation_data=test_set,
#                                    epochs=10,
#                                    validation_steps=test_set.samples//batch_size)

# Stop time
stop_time = datetime.now()
print("stop time: "+str(stop_time))

total_time = stop_time - start_time
print("Total time: "+str(total_time))
# Out:
# start time: 2021-12-29 17:15:38.465797
# C:\Users\USER\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\data\ops\dataset_ops.py:3504: UserWarning: Even though the tf.config.experimental_run_functions_eagerly option is set, this option does not apply to tf.data functions. tf.data functions are still traced and executed as graphs.
#   "Even though the tf.config.experimental_run_functions_eagerly "
# Epoch 1/100
# 473/473 [==============================] - 146s 304ms/step - loss: 1.0511 - accuracy: 0.6653 - val_loss: 1.7356 - val_accuracy: 0.6186
#
# Epoch 00001: val_loss improved from inf to 1.73563, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 2/100
# 473/473 [==============================] - 136s 288ms/step - loss: 0.5213 - accuracy: 0.8234 - val_loss: 1.3700 - val_accuracy: 0.6335
#
# Epoch 00002: val_loss improved from 1.73563 to 1.36998, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 3/100
# 473/473 [==============================] - 136s 288ms/step - loss: 0.3907 - accuracy: 0.8678 - val_loss: 7.6756 - val_accuracy: 0.3120
#
# Epoch 00003: val_loss did not improve from 1.36998
# Epoch 4/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.3675 - accuracy: 0.8732 - val_loss: 1.0826 - val_accuracy: 0.7066
#
# Epoch 00004: val_loss improved from 1.36998 to 1.08258, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 5/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.3257 - accuracy: 0.8888 - val_loss: 0.8610 - val_accuracy: 0.7654
#
# Epoch 00005: val_loss improved from 1.08258 to 0.86096, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 6/100
# 473/473 [==============================] - 138s 291ms/step - loss: 0.2418 - accuracy: 0.9166 - val_loss: 2.0044 - val_accuracy: 0.6149
#
# Epoch 00006: val_loss did not improve from 0.86096
# Epoch 7/100
# 473/473 [==============================] - 139s 293ms/step - loss: 0.2389 - accuracy: 0.9139 - val_loss: 1.4112 - val_accuracy: 0.6388
#
# Epoch 00007: val_loss did not improve from 0.86096
# Epoch 8/100
# 473/473 [==============================] - 139s 293ms/step - loss: 0.2164 - accuracy: 0.9276 - val_loss: 2.5675 - val_accuracy: 0.6462
#
# Epoch 00008: val_loss did not improve from 0.86096
# Epoch 9/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.2019 - accuracy: 0.9294 - val_loss: 1.4317 - val_accuracy: 0.6901
#
# Epoch 00009: val_loss did not improve from 0.86096
# Epoch 10/100
# 473/473 [==============================] - 137s 290ms/step - loss: 0.1772 - accuracy: 0.9400 - val_loss: 0.4599 - val_accuracy: 0.8819
#
# Epoch 00010: val_loss improved from 0.86096 to 0.45988, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 11/100
# 473/473 [==============================] - 138s 292ms/step - loss: 0.1581 - accuracy: 0.9434 - val_loss: 0.5454 - val_accuracy: 0.8300
#
# Epoch 00011: val_loss did not improve from 0.45988
# Epoch 12/100
# 473/473 [==============================] - 138s 291ms/step - loss: 0.1562 - accuracy: 0.9467 - val_loss: 0.5508 - val_accuracy: 0.8522
#
# Epoch 00012: val_loss did not improve from 0.45988
# Epoch 13/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.1357 - accuracy: 0.9547 - val_loss: 5.2292 - val_accuracy: 0.5079
#
# Epoch 00013: val_loss did not improve from 0.45988
# Epoch 14/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.1356 - accuracy: 0.9514 - val_loss: 1.6044 - val_accuracy: 0.7426
#
# Epoch 00014: val_loss did not improve from 0.45988
# Epoch 15/100
# 473/473 [==============================] - 137s 288ms/step - loss: 0.1318 - accuracy: 0.9536 - val_loss: 0.4698 - val_accuracy: 0.8591
#
# Epoch 00015: val_loss did not improve from 0.45988
# Epoch 16/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.1337 - accuracy: 0.9547 - val_loss: 1.6227 - val_accuracy: 0.7574
#
# Epoch 00016: val_loss did not improve from 0.45988
# Epoch 17/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.1159 - accuracy: 0.9604 - val_loss: 0.4986 - val_accuracy: 0.8469
#
# Epoch 00017: val_loss did not improve from 0.45988
# Epoch 18/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.1223 - accuracy: 0.9592 - val_loss: 0.4944 - val_accuracy: 0.8745
#
# Epoch 00018: val_loss did not improve from 0.45988
# Epoch 19/100
# 473/473 [==============================] - 137s 290ms/step - loss: 0.0982 - accuracy: 0.9663 - val_loss: 1.3588 - val_accuracy: 0.8141
#
# Epoch 00019: val_loss did not improve from 0.45988
# Epoch 20/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.0987 - accuracy: 0.9680 - val_loss: 1.1468 - val_accuracy: 0.7532
#
# Epoch 00020: val_loss did not improve from 0.45988
# Epoch 21/100
# 473/473 [==============================] - 138s 291ms/step - loss: 0.1212 - accuracy: 0.9581 - val_loss: 0.6762 - val_accuracy: 0.8024
#
# Epoch 00021: val_loss did not improve from 0.45988
# Epoch 22/100
# 473/473 [==============================] - 138s 292ms/step - loss: 0.1036 - accuracy: 0.9622 - val_loss: 0.5788 - val_accuracy: 0.8490
#
# Epoch 00022: val_loss did not improve from 0.45988
# Epoch 23/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.0904 - accuracy: 0.9684 - val_loss: 5.2846 - val_accuracy: 0.5508
#
# Epoch 00023: val_loss did not improve from 0.45988
# Epoch 24/100
# 473/473 [==============================] - 136s 288ms/step - loss: 0.1010 - accuracy: 0.9653 - val_loss: 0.5609 - val_accuracy: 0.8623
#
# Epoch 00024: val_loss did not improve from 0.45988
# Epoch 25/100
# 473/473 [==============================] - 135s 284ms/step - loss: 0.1003 - accuracy: 0.9660 - val_loss: 0.1607 - val_accuracy: 0.9492
#
# Epoch 00025: val_loss improved from 0.45988 to 0.16068, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 26/100
# 473/473 [==============================] - 135s 285ms/step - loss: 0.0756 - accuracy: 0.9717 - val_loss: 3.7959 - val_accuracy: 0.5847
#
# Epoch 00026: val_loss did not improve from 0.16068
# Epoch 27/100
# 473/473 [==============================] - 135s 284ms/step - loss: 0.1015 - accuracy: 0.9663 - val_loss: 0.4940 - val_accuracy: 0.8660
#
# Epoch 00027: val_loss did not improve from 0.16068
# Epoch 28/100
# 473/473 [==============================] - 135s 284ms/step - loss: 0.0822 - accuracy: 0.9721 - val_loss: 0.8351 - val_accuracy: 0.7754
#
# Epoch 00028: val_loss did not improve from 0.16068
# Epoch 29/100
# 473/473 [==============================] - 134s 284ms/step - loss: 0.0761 - accuracy: 0.9711 - val_loss: 0.1774 - val_accuracy: 0.9423
#
# Epoch 00029: val_loss did not improve from 0.16068
# Epoch 30/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0783 - accuracy: 0.9727 - val_loss: 0.1880 - val_accuracy: 0.9539
#
# Epoch 00030: val_loss did not improve from 0.16068
# Epoch 31/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0821 - accuracy: 0.9729 - val_loss: 0.1525 - val_accuracy: 0.9460
#
# Epoch 00031: val_loss improved from 0.16068 to 0.15248, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 32/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0602 - accuracy: 0.9787 - val_loss: 0.1218 - val_accuracy: 0.9582
#
# Epoch 00032: val_loss improved from 0.15248 to 0.12178, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 33/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0638 - accuracy: 0.9778 - val_loss: 1.5706 - val_accuracy: 0.7579
#
# Epoch 00033: val_loss did not improve from 0.12178
# Epoch 34/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0807 - accuracy: 0.9720 - val_loss: 0.0772 - val_accuracy: 0.9725
#
# Epoch 00034: val_loss improved from 0.12178 to 0.07721, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 35/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0568 - accuracy: 0.9799 - val_loss: 0.1125 - val_accuracy: 0.9661
#
# Epoch 00035: val_loss did not improve from 0.07721
# Epoch 36/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0737 - accuracy: 0.9751 - val_loss: 0.0851 - val_accuracy: 0.9746
#
# Epoch 00036: val_loss did not improve from 0.07721
# Epoch 37/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0595 - accuracy: 0.9771 - val_loss: 1.4204 - val_accuracy: 0.7495
#
# Epoch 00037: val_loss did not improve from 0.07721
# Epoch 38/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0583 - accuracy: 0.9817 - val_loss: 0.1670 - val_accuracy: 0.9449
#
# Epoch 00038: val_loss did not improve from 0.07721
# Epoch 39/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0567 - accuracy: 0.9799 - val_loss: 1.5360 - val_accuracy: 0.8130
#
# Epoch 00039: val_loss did not improve from 0.07721
# Epoch 40/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0651 - accuracy: 0.9782 - val_loss: 0.3771 - val_accuracy: 0.9168
#
# Epoch 00040: val_loss did not improve from 0.07721
# Epoch 41/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0552 - accuracy: 0.9820 - val_loss: 13.7655 - val_accuracy: 0.2977
#
# Epoch 00041: val_loss did not improve from 0.07721
# Epoch 42/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0568 - accuracy: 0.9781 - val_loss: 0.1204 - val_accuracy: 0.9629
#
# Epoch 00042: val_loss did not improve from 0.07721
# Epoch 43/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0515 - accuracy: 0.9827 - val_loss: 0.0825 - val_accuracy: 0.9751
#
# Epoch 00043: val_loss did not improve from 0.07721
# Epoch 44/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0531 - accuracy: 0.9816 - val_loss: 0.3588 - val_accuracy: 0.9206
#
# Epoch 00044: val_loss did not improve from 0.07721
# Epoch 45/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0505 - accuracy: 0.9825 - val_loss: 0.1997 - val_accuracy: 0.9380
#
# Epoch 00045: val_loss did not improve from 0.07721
# Epoch 46/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0543 - accuracy: 0.9799 - val_loss: 1.0235 - val_accuracy: 0.7865
#
# Epoch 00046: val_loss did not improve from 0.07721
# Epoch 47/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0598 - accuracy: 0.9785 - val_loss: 0.2472 - val_accuracy: 0.9322
#
# Epoch 00047: val_loss did not improve from 0.07721
# Epoch 48/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0465 - accuracy: 0.9844 - val_loss: 0.3983 - val_accuracy: 0.8967
#
# Epoch 00048: val_loss did not improve from 0.07721
# Epoch 49/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0403 - accuracy: 0.9859 - val_loss: 0.0939 - val_accuracy: 0.9693
#
# Epoch 00049: val_loss did not improve from 0.07721
# Epoch 50/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0473 - accuracy: 0.9825 - val_loss: 1.0942 - val_accuracy: 0.8046
#
# Epoch 00050: val_loss did not improve from 0.07721
# Epoch 51/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0473 - accuracy: 0.9841 - val_loss: 0.1169 - val_accuracy: 0.9603
#
# Epoch 00051: val_loss did not improve from 0.07721
# Epoch 52/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0442 - accuracy: 0.9853 - val_loss: 0.1423 - val_accuracy: 0.9650
#
# Epoch 00052: val_loss did not improve from 0.07721
# Epoch 53/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0542 - accuracy: 0.9799 - val_loss: 0.8019 - val_accuracy: 0.8289
#
# Epoch 00053: val_loss did not improve from 0.07721
# Epoch 54/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0431 - accuracy: 0.9854 - val_loss: 0.0389 - val_accuracy: 0.9857
#
# Epoch 00054: val_loss improved from 0.07721 to 0.03889, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 55/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0367 - accuracy: 0.9867 - val_loss: 0.1199 - val_accuracy: 0.9566
#
# Epoch 00055: val_loss did not improve from 0.03889
# Epoch 56/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0342 - accuracy: 0.9878 - val_loss: 0.1996 - val_accuracy: 0.9460
#
# Epoch 00056: val_loss did not improve from 0.03889
# Epoch 57/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0366 - accuracy: 0.9878 - val_loss: 0.6097 - val_accuracy: 0.8565
#
# Epoch 00057: val_loss did not improve from 0.03889
# Epoch 58/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0398 - accuracy: 0.9857 - val_loss: 0.2881 - val_accuracy: 0.9386
#
# Epoch 00058: val_loss did not improve from 0.03889
# Epoch 59/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0397 - accuracy: 0.9862 - val_loss: 0.5114 - val_accuracy: 0.9094
#
# Epoch 00059: val_loss did not improve from 0.03889
# Epoch 60/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0374 - accuracy: 0.9862 - val_loss: 0.0994 - val_accuracy: 0.9645
#
# Epoch 00060: val_loss did not improve from 0.03889
# Epoch 61/100
# 473/473 [==============================] - 135s 285ms/step - loss: 0.0430 - accuracy: 0.9842 - val_loss: 0.0401 - val_accuracy: 0.9857
#
# Epoch 00061: val_loss did not improve from 0.03889
# Epoch 62/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0335 - accuracy: 0.9875 - val_loss: 0.1655 - val_accuracy: 0.9571
#
# Epoch 00062: val_loss did not improve from 0.03889
# Epoch 63/100
# 473/473 [==============================] - 135s 285ms/step - loss: 0.0401 - accuracy: 0.9864 - val_loss: 0.2899 - val_accuracy: 0.9433
#
# Epoch 00063: val_loss did not improve from 0.03889
# Epoch 64/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0429 - accuracy: 0.9854 - val_loss: 0.8265 - val_accuracy: 0.8496
#
# Epoch 00064: val_loss did not improve from 0.03889
# Epoch 65/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0285 - accuracy: 0.9896 - val_loss: 0.0615 - val_accuracy: 0.9793
#
# Epoch 00065: val_loss did not improve from 0.03889
# Epoch 66/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0424 - accuracy: 0.9860 - val_loss: 0.2642 - val_accuracy: 0.9386
#
# Epoch 00066: val_loss did not improve from 0.03889
# Epoch 67/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0339 - accuracy: 0.9883 - val_loss: 0.9144 - val_accuracy: 0.8554
#
# Epoch 00067: val_loss did not improve from 0.03889
# Epoch 68/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0412 - accuracy: 0.9852 - val_loss: 1.0981 - val_accuracy: 0.8480
#
# Epoch 00068: val_loss did not improve from 0.03889
# Epoch 69/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0275 - accuracy: 0.9904 - val_loss: 0.1150 - val_accuracy: 0.9666
#
# Epoch 00069: val_loss did not improve from 0.03889
# Epoch 70/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0429 - accuracy: 0.9860 - val_loss: 0.0614 - val_accuracy: 0.9799
#
# Epoch 00070: val_loss did not improve from 0.03889
# Epoch 71/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0282 - accuracy: 0.9901 - val_loss: 0.1009 - val_accuracy: 0.9725
#
# Epoch 00071: val_loss did not improve from 0.03889
# Epoch 72/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0308 - accuracy: 0.9886 - val_loss: 0.1204 - val_accuracy: 0.9661
#
# Epoch 00072: val_loss did not improve from 0.03889
# Epoch 73/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0358 - accuracy: 0.9872 - val_loss: 1.2396 - val_accuracy: 0.8231
#
# Epoch 00073: val_loss did not improve from 0.03889
# Epoch 74/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0369 - accuracy: 0.9877 - val_loss: 0.1110 - val_accuracy: 0.9677
#
# Epoch 00074: val_loss did not improve from 0.03889
# Epoch 75/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0375 - accuracy: 0.9875 - val_loss: 0.2542 - val_accuracy: 0.9296
#
# Epoch 00075: val_loss did not improve from 0.03889
# Epoch 76/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0289 - accuracy: 0.9898 - val_loss: 4.7416 - val_accuracy: 0.7097
#
# Epoch 00076: val_loss did not improve from 0.03889
# Epoch 77/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0369 - accuracy: 0.9872 - val_loss: 0.1096 - val_accuracy: 0.9693
#
# Epoch 00077: val_loss did not improve from 0.03889
# Epoch 78/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0289 - accuracy: 0.9896 - val_loss: 0.0287 - val_accuracy: 0.9910
# Epoch 00078: val_loss improved from 0.03889 to 0.02869, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 79/100
# 473/473 [==============================] - 137s 289ms/step - loss: 0.0283 - accuracy: 0.9909 - val_loss: 0.2763 - val_accuracy: 0.9248
#
# Epoch 00079: val_loss did not improve from 0.02869
# Epoch 80/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0286 - accuracy: 0.9897 - val_loss: 9.3146 - val_accuracy: 0.5201
#
# Epoch 00080: val_loss did not improve from 0.02869
# Epoch 81/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0366 - accuracy: 0.9860 - val_loss: 0.1861 - val_accuracy: 0.9529
#
# Epoch 00081: val_loss did not improve from 0.02869
# Epoch 82/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0221 - accuracy: 0.9907 - val_loss: 4.1814 - val_accuracy: 0.7119
#
# Epoch 00082: val_loss did not improve from 0.02869
# Epoch 83/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0334 - accuracy: 0.9878 - val_loss: 0.0419 - val_accuracy: 0.9836
#
# Epoch 00083: val_loss did not improve from 0.02869
# Epoch 84/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 1.3693 - val_accuracy: 0.7680
#
# Epoch 00084: val_loss did not improve from 0.02869
# Epoch 85/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0323 - accuracy: 0.9898 - val_loss: 1.0231 - val_accuracy: 0.8565
#
# Epoch 00085: val_loss did not improve from 0.02869
# Epoch 86/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0222 - accuracy: 0.9918 - val_loss: 0.0654 - val_accuracy: 0.9820
#
# Epoch 00086: val_loss did not improve from 0.02869
# Epoch 87/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0280 - accuracy: 0.9909 - val_loss: 1.3838 - val_accuracy: 0.8374
#
# Epoch 00087: val_loss did not improve from 0.02869
# Epoch 88/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 0.0448 - val_accuracy: 0.9857
#
# Epoch 00088: val_loss did not improve from 0.02869
# Epoch 89/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0258 - accuracy: 0.9908 - val_loss: 0.0457 - val_accuracy: 0.9852
#
# Epoch 00089: val_loss did not improve from 0.02869
# Epoch 90/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0343 - accuracy: 0.9887 - val_loss: 0.0328 - val_accuracy: 0.9947
#
# Epoch 00090: val_loss did not improve from 0.02869
# Epoch 91/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0203 - accuracy: 0.9934 - val_loss: 0.2793 - val_accuracy: 0.9417
#
# Epoch 00091: val_loss did not improve from 0.02869
# Epoch 92/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0266 - accuracy: 0.9915 - val_loss: 0.3199 - val_accuracy: 0.9370
#
# Epoch 00092: val_loss did not improve from 0.02869
# Epoch 93/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0205 - accuracy: 0.9924 - val_loss: 0.0597 - val_accuracy: 0.9820
#
# Epoch 00093: val_loss did not improve from 0.02869
# Epoch 94/100
# 473/473 [==============================] - 136s 286ms/step - loss: 0.0267 - accuracy: 0.9906 - val_loss: 0.2392 - val_accuracy: 0.9481
#
# Epoch 00094: val_loss did not improve from 0.02869
# Epoch 95/100
# 473/473 [==============================] - 136s 287ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 0.2916 - val_accuracy: 0.9364
#
# Epoch 00095: val_loss did not improve from 0.02869
# Epoch 96/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0312 - accuracy: 0.9910 - val_loss: 0.2701 - val_accuracy: 0.9322
#
# Epoch 00096: val_loss did not improve from 0.02869
# Epoch 97/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0219 - accuracy: 0.9921 - val_loss: 0.0191 - val_accuracy: 0.9931
#
# Epoch 00097: val_loss improved from 0.02869 to 0.01914, saving model to CBAM-keras/saved_models\LW_ResNet20_da_module_tomato_adam_100_epochs.hdf5
# Epoch 98/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.2108 - val_accuracy: 0.9391
#
# Epoch 00098: val_loss did not improve from 0.01914
# Epoch 99/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0258 - accuracy: 0.9914 - val_loss: 0.0979 - val_accuracy: 0.9709
#
# Epoch 00099: val_loss did not improve from 0.01914
# Epoch 100/100
# 473/473 [==============================] - 135s 286ms/step - loss: 0.0293 - accuracy: 0.9893 - val_loss: 0.0913 - val_accuracy: 0.9793
#
# Epoch 00100: val_loss did not improve from 0.01914
# stop time: 2021-12-29 21:02:05.741166
# Total time: 3:46:27.275369

# %%
# another way to save it.
import pandas as pd
hist_df = pd.DataFrame(history.history) 
hist_csv_file = "CBAM-keras/saved_models/LW_ResNet20_da_module_tomato_adam_100_epochs.csv"
# hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w', newline='') as f:
    hist_df.to_csv(f)
